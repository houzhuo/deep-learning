# %%
import cv2
import numpy as np
import dlib
import time
import math
from Package import imutils
import csv

detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("C:/Users/lll/Documents/hz/shape_predictor_68_face_landmarks.dat")
POINTS_NUM_LANDMARK = 68

# 获取最大的人脸
def _largest_face(dets):
    if len(dets) == 1:
        return 0

    face_areas = [ (det.right()-det.left())*(det.bottom()-det.top()) for det in dets]

    largest_area = face_areas[0]
    largest_index = 0
    for index in range(1, len(dets)):
        if face_areas[index] > largest_area :
            largest_index = index
            largest_area = face_areas[index]

    print("largest_face index is {} in {} faces".format(largest_index, len(dets)))

    return largest_index

# 从dlib的检测结果抽取姿态估计需要的点坐标
def get_image_points_from_landmark_shape(landmark_shape):
    if landmark_shape.num_parts != POINTS_NUM_LANDMARK:
        print("ERROR:landmark_shape.num_parts-{}".format(landmark_shape.num_parts))
        return -1, None
    
    #2D image points. If you change the image, you need to change vector
    image_points = np.array([
                                (landmark_shape.part(30).x, landmark_shape.part(30).y),     # Nose tip
                                (landmark_shape.part(8).x, landmark_shape.part(8).y),     # Chin
                                (landmark_shape.part(36).x, landmark_shape.part(36).y),     # Left eye left corner
                                (landmark_shape.part(45).x, landmark_shape.part(45).y),     # Right eye right corne
                                (landmark_shape.part(48).x, landmark_shape.part(48).y),     # Left Mouth corner
                                (landmark_shape.part(54).x, landmark_shape.part(54).y)      # Right mouth corner
                            ], dtype="double")

    return 0, image_points
    
# 用dlib检测关键点，返回姿态估计需要的几个点坐标
def get_image_points(img):
                            
    #gray = cv2.cvtColor( img, cv2.COLOR_BGR2GRAY )  # 图片调整为灰色
    dets = detector( img, 0 )

    if 0 == len( dets ):
        print( "ERROR: found no face" )
        return -1, None
    largest_index = _largest_face(dets)
    face_rectangle = dets[largest_index]

    landmark_shape = predictor(img, face_rectangle)

    return get_image_points_from_landmark_shape(landmark_shape)


# 获取旋转向量和平移向量                        
def get_pose_estimation(img_size, image_points ):
    # 3D model points.
    model_points = np.array([
                                (0.0, 0.0, 0.0),             # Nose tip
                                (0.0, -330.0, -65.0),        # Chin
                                (-225.0, 170.0, -135.0),     # Left eye left corner
                                (225.0, 170.0, -135.0),      # Right eye right corne
                                (-150.0, -150.0, -125.0),    # Left Mouth corner
                                (150.0, -150.0, -125.0)      # Right mouth corner
                             
                            ])
     
    # Camera internals
     
    focal_length = img_size[1]
    center = (img_size[1]/2, img_size[0]/2)
    camera_matrix = np.array(
                             [[focal_length, 0, center[0]],
                             [0, focal_length, center[1]],
                             [0, 0, 1]], dtype = "double"
                             )
     
    #print("Camera Matrix :{}".format(camera_matrix))
     
    dist_coeffs = np.zeros((4,1)) # Assuming no lens distortion
    (success, rotation_vector, translation_vector) = cv2.solvePnP(model_points, image_points, camera_matrix, dist_coeffs, flags=cv2.SOLVEPNP_ITERATIVE )
 
    #print("Rotation Vector:\n {}".format(rotation_vector))
    #print("Translation Vector:\n {}".format(translation_vector))
    return success, rotation_vector, translation_vector, camera_matrix, dist_coeffs

# 从旋转向量转换为欧拉角
def get_euler_angle(rotation_vector):
    #print(rotation_vector[0],rotation_vector[1])
    # calculate rotation angles
    theta = cv2.norm(rotation_vector, cv2.NORM_L2)
    
    # transformed to quaterniond
    w = math.cos(theta / 2)
    x = math.sin(theta / 2)*rotation_vector[0][0] / theta
    y = math.sin(theta / 2)*rotation_vector[1][0] / theta
    z = math.sin(theta / 2)*rotation_vector[2][0] / theta
    
    ysqr = y * y
    # pitch (x-axis rotation)
    t0 = 2.0 * (w * x + y * z)
    t1 = 1.0 - 2.0 * (x * x + ysqr)
    #print('t0:{}, t1:{}'.format(t0, t1))
    pitch = math.atan2(t0, t1)
    
    # yaw (y-axis rotation)
    t2 = 2.0 * (w * y - z * x)
    if t2 > 1.0:
        t2 = 1.0
    if t2 < -1.0:
        t2 = -1.0
    yaw = math.asin(t2)
    
    # roll (z-axis rotation)
    t3 = 2.0 * (w * z + x * y)
    t4 = 1.0 - 2.0 * (ysqr + z * z)
    roll = math.atan2(t3, t4)
    
    #print('pitch:{}, yaw:{}, roll:{}'.format(pitch, yaw, roll))
    
	# 单位转换：将弧度转换为度
    Y = int((pitch/math.pi)*180)
    X = int((yaw/math.pi)*180)
    Z = int((roll/math.pi)*180)
    
    return 0, Y, X, Z


# def get_pose_estimation_in_euler_angle(landmark_shape, im_szie):
#     try:
#         ret, image_points = get_image_points_from_landmark_shape(landmark_shape)
#         if ret != 0:
#             print('get_image_points failed')
#             return -1, None, None, None
    
#         ret, rotation_vector, translation_vector, camera_matrix, dist_coeffs = get_pose_estimation(im_szie, image_points)
#         if ret != True:
#             print('get_pose_estimation failed')
#             return -1, None, None, None
    
#         ret, pitch, yaw, roll = get_euler_angle(rotation_vector)
#         if ret != 0:
#             print('get_euler_angle failed')
#             return -1, None, None, None

#         euler_angle_str = 'Y:{}, X:{}, Z:{}'.format(pitch, yaw, roll)
#         print(euler_angle_str)
#         return 0, pitch, yaw, roll
    
#     except Exception as e:
#         print('get_pose_estimation_in_euler_angle exception:{}'.format(e))
#         return -1, None, None, None
        
with open('player_yurei_frame.csv', mode='w',newline ='') as csvfile:
    fieldnames = ['Y', 'X', 'Z']
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    camera =cv2.VideoCapture("C:/Users/lll/Documents/hz/conda/images/yurei.mp4",0)

    fps = camera.get(cv2.CAP_PROP_FPS)
    print("fps",fps)
    count = 0
    while True:

        ret, im = camera.read()
        im = im[269: 795, 337: 1000]
        #print(ret,im)
        if not ret:
            break

        # Read Image

        if ret != True:
            print('read frame failed')
            
            continue
        size = im.shape

        if size[0] > 700:
            h = size[0] / 2
            w = size[1] / 2
            im = cv2.resize( im, (int( w ), int( h )), interpolation=cv2.INTER_CUBIC )
            size = im.shape

        ret, image_points = get_image_points(im)
        if ret != 0:
            print('get_image_points failed')
            writer.writerow({'Y': 0, 'X':0, 'Z': 0})
            count+=1
            continue

        ret, rotation_vector, translation_vector, camera_matrix, dist_coeffs = get_pose_estimation(size, image_points)
        if ret != True:
            print('get_pose_estimation failed')

            continue

        ret, pitch, yaw, roll = get_euler_angle(rotation_vector)
        euler_angle_str = 'Y:{}, X:{}, Z:{}'.format(pitch, yaw, roll)
        print(euler_angle_str)
        writer.writerow({'Y': pitch, 'X':yaw, 'Z': roll})
        count+=1
        # Project a 3D point (0, 0, 1000.0) onto the image plane.
        # We use this to draw a line sticking out of the nose

        (nose_end_point2D, jacobian) = cv2.projectPoints(np.array([(0.0, 0.0, 1000.0)]), rotation_vector, translation_vector, camera_matrix, dist_coeffs)

        for p in image_points:
            cv2.circle(im, (int(p[0]), int(p[1])), 3, (0,0,255), -1)


        p1 = ( int(image_points[0][0]), int(image_points[0][1]))
        p2 = ( int(nose_end_point2D[0][0][0]), int(nose_end_point2D[0][0][1]))
        
        cv2.line(im, p1, p2, (255,0,0), 2)

        # Display image
        #cv2.putText( im, str(rotation_vector), (0, 100), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1 )
        cv2.putText( im, euler_angle_str, (0, 120), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1 )
        cv2.imshow("Output", im)
        cv2.waitKey(1)
        print("frame:",count)
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    camera.release()
    cv2.destroyAllWindows()

    
#!/usr/bin/env python
# Out:
# fps 29.97002997002997
# largest_face index is 0 in 2 faces
# Y:166, X:-41, Z:-1
# frame: 1
# largest_face index is 0 in 2 faces
# Y:166, X:-41, Z:-1
# frame: 2
# largest_face index is 0 in 2 faces
# Y:166, X:-36, Z:-5
# frame: 3
# Y:170, X:-27, Z:-5
# frame: 4
# Y:172, X:-30, Z:-6
# frame: 5
# Y:177, X:-27, Z:-8
# frame: 6
# Y:174, X:-4, Z:-13
# frame: 7
# largest_face index is 1 in 2 faces
# Y:-167, X:-14, Z:162
# frame: 8
# largest_face index is 0 in 2 faces
# Y:165, X:-27, Z:-7
# frame: 9
# Y:166, X:-29, Z:-7
# frame: 10
# Y:164, X:-28, Z:-6
# frame: 11
# largest_face index is 0 in 3 faces
# Y:164, X:-34, Z:-4
# frame: 12
# largest_face index is 0 in 2 faces
# Y:165, X:-28, Z:-5
# frame: 13
# largest_face index is 0 in 2 faces
# Y:166, X:-35, Z:-3
# frame: 14
# largest_face index is 0 in 2 faces
# Y:165, X:-16, Z:-9
# frame: 15
# largest_face index is 0 in 2 faces
# Y:165, X:-37, Z:-1
# frame: 16
# largest_face index is 0 in 2 faces
# Y:165, X:-39, Z:0
# frame: 17
# largest_face index is 0 in 2 faces
# Y:163, X:-41, Z:0
# frame: 18
# largest_face index is 0 in 2 faces
# Y:167, X:-40, Z:0
# frame: 19
# largest_face index is 0 in 2 faces
# Y:167, X:-47, Z:1
# frame: 20
# largest_face index is 0 in 2 faces
# Y:168, X:-44, Z:0
# frame: 21
# largest_face index is 0 in 2 faces
# Y:167, X:9, Z:-14
# frame: 22
# largest_face index is 0 in 2 faces
# Y:169, X:-45, Z:0
# frame: 23
# largest_face index is 0 in 2 faces
# Y:168, X:5, Z:-14
# frame: 24
# largest_face index is 0 in 2 faces
# Y:168, X:10, Z:-14
# frame: 25
# largest_face index is 0 in 2 faces
# Y:169, X:-49, Z:1
# frame: 26
# largest_face index is 1 in 2 faces
# Y:169, X:-45, Z:0
# frame: 27
# largest_face index is 0 in 2 faces
# Y:168, X:-45, Z:1
# frame: 28
# largest_face index is 0 in 2 faces
# Y:170, X:8, Z:-13
# frame: 29
# largest_face index is 0 in 2 faces
# Y:171, X:-54, Z:2
# frame: 30
# largest_face index is 0 in 2 faces
# Y:170, X:-52, Z:2
# frame: 31
# largest_face index is 0 in 2 faces
# Y:171, X:-50, Z:0
# frame: 32
# largest_face index is 1 in 2 faces
# Y:172, X:-50, Z:0
# frame: 33
# largest_face index is 0 in 2 faces
# Y:174, X:-50, Z:0
# frame: 34
# largest_face index is 0 in 2 faces
# Y:175, X:-52, Z:0
# frame: 35
# largest_face index is 0 in 2 faces
# Y:175, X:-50, Z:-1
# frame: 36
# largest_face index is 0 in 2 faces
# Y:178, X:-53, Z:-2
# frame: 37
# largest_face index is 0 in 2 faces
# Y:178, X:-50, Z:-3
# frame: 38
# largest_face index is 0 in 2 faces
# Y:178, X:-51, Z:-3
# frame: 39
# Y:176, X:-50, Z:-2
# frame: 40
# largest_face index is 0 in 2 faces
# Y:176, X:-51, Z:-2
# frame: 41
# largest_face index is 0 in 2 faces
# Y:175, X:-51, Z:-1
# frame: 42
# largest_face index is 0 in 2 faces
# Y:176, X:-52, Z:-1
# frame: 43
# largest_face index is 0 in 2 faces
# Y:179, X:-52, Z:-4
# frame: 44
# largest_face index is 0 in 2 faces
# Y:179, X:-52, Z:-4
# frame: 45
# largest_face index is 0 in 2 faces
# Y:176, X:-52, Z:-2
# frame: 46
# largest_face index is 0 in 2 faces
# Y:178, X:-53, Z:-2
# frame: 47
# largest_face index is 0 in 2 faces
# Y:177, X:-54, Z:-1
# frame: 48
# largest_face index is 0 in 2 faces
# Y:178, X:-47, Z:-2
# frame: 49
# largest_face index is 0 in 2 faces
# Y:178, X:-53, Z:-1
# frame: 50
# largest_face index is 0 in 2 faces
# Y:-178, X:-48, Z:-4
# frame: 51
# largest_face index is 0 in 2 faces
# Y:-179, X:-51, Z:-2
# frame: 52
# Y:-178, X:-52, Z:-3
# frame: 53
# Y:-177, X:-51, Z:-4
# frame: 54
# largest_face index is 0 in 2 faces
# Y:-178, X:-50, Z:-2
# frame: 55
# Y:-177, X:-51, Z:-3
# frame: 56
# Y:-179, X:-50, Z:-2
# frame: 57
# Y:179, X:-52, Z:0
# frame: 58
# Y:178, X:-52, Z:0
# frame: 59
# Y:178, X:-52, Z:0
# frame: 60
# Y:178, X:-52, Z:0
# frame: 61
# Y:179, X:-36, Z:2
# frame: 62
# Y:179, X:-49, Z:2
# frame: 63
# Y:179, X:-49, Z:0
# frame: 64
# Y:-179, X:-48, Z:-1
# frame: 65
# Y:-177, X:-47, Z:-1
# frame: 66
# Y:179, X:-51, Z:0
# frame: 67
# Y:179, X:-50, Z:0
# frame: 68
# largest_face index is 0 in 2 faces
# Y:-179, X:-50, Z:0
# frame: 69
# Y:179, X:-52, Z:0
# frame: 70
# largest_face index is 0 in 2 faces
# Y:179, X:-50, Z:0
# frame: 71
# Y:179, X:-50, Z:0
# frame: 72
# Y:-179, X:-50, Z:0
# frame: 73
# Y:-177, X:-50, Z:-1
# frame: 74
# Y:-179, X:-51, Z:0
# frame: 75
# Y:-179, X:-50, Z:0
# frame: 76
# Y:-179, X:-49, Z:0
# frame: 77
# Y:-178, X:-51, Z:0
# frame: 78
# Y:-179, X:-51, Z:0
# frame: 79
# Y:-178, X:-50, Z:0
# frame: 80
# Y:179, X:-52, Z:1
# frame: 81
# Y:178, X:-51, Z:0
# frame: 82
# Y:179, X:-44, Z:1
# frame: 83
# Y:-175, X:-51, Z:-2
# frame: 84
# Y:-176, X:-52, Z:-2
# frame: 85
# Y:-172, X:-52, Z:-5
# frame: 86
# Y:179, X:-49, Z:0
# frame: 87
# Y:-171, X:-50, Z:-4
# frame: 88
# Y:-174, X:-54, Z:-4
# frame: 89
# Y:-179, X:-54, Z:-1
# frame: 90
# Y:-177, X:-55, Z:-3
# frame: 91
# Y:-175, X:-57, Z:-5
# frame: 92
# Y:-178, X:-55, Z:-2
# frame: 93
# Y:-167, X:-50, Z:-8
# frame: 94
# Y:-168, X:-58, Z:-7
# frame: 95
# Y:-170, X:-59, Z:-7
# frame: 96
# Y:-169, X:-59, Z:-6
# frame: 97
# Y:-173, X:-57, Z:-4
# frame: 98
# Y:-175, X:-58, Z:-5
# frame: 99
# Y:171, X:-36, Z:12
# frame: 100
# Y:173, X:-41, Z:16
# frame: 101
# Y:174, X:-46, Z:6
# frame: 102
# Y:169, X:-36, Z:11
# frame: 103
# Y:169, X:-38, Z:14
# frame: 104
# Y:170, X:-46, Z:7
# frame: 105
# Y:171, X:-43, Z:11
# frame: 106
# largest_face index is 0 in 2 faces
# Y:165, X:-30, Z:10
# frame: 107
# largest_face index is 0 in 2 faces
# Y:172, X:-41, Z:12
# frame: 108
# Y:171, X:-34, Z:8
# frame: 109
# Y:167, X:-33, Z:8
# frame: 110
# largest_face index is 0 in 2 faces
# Y:164, X:-32, Z:9
# frame: 111
# Y:175, X:-36, Z:2
# frame: 112
# Y:174, X:-44, Z:2
# frame: 113
# Y:176, X:-43, Z:7
# frame: 114
# largest_face index is 0 in 2 faces
# Y:175, X:-49, Z:3
# frame: 115
# largest_face index is 0 in 2 faces
# Y:177, X:-50, Z:3
# frame: 116
# Y:-178, X:-52, Z:0
# frame: 117
# Y:178, X:-46, Z:3
# frame: 118
# Y:175, X:-47, Z:4
# frame: 119
# Y:177, X:-48, Z:5
# frame: 120
# Y:177, X:-49, Z:2
# frame: 121
# Y:174, X:-49, Z:5
# frame: 122
# Y:178, X:-50, Z:2
# frame: 123
# Y:177, X:-49, Z:3
# frame: 124
# Y:175, X:-49, Z:4
# frame: 125
# largest_face index is 0 in 2 faces
# Y:177, X:-47, Z:4
# frame: 126
# largest_face index is 0 in 2 faces
# Y:179, X:-46, Z:3
# frame: 127
# largest_face index is 0 in 2 faces
# Y:-175, X:-45, Z:1
# frame: 128
# largest_face index is 0 in 2 faces
# Y:179, X:-55, Z:1
# frame: 129
# Y:-178, X:-55, Z:0
# frame: 130
# Y:-179, X:-55, Z:1
# frame: 131
# Y:-179, X:-55, Z:0
# frame: 132
# Y:179, X:-55, Z:1
# frame: 133
# Y:-178, X:-55, Z:0
# frame: 134
# Y:-177, X:-55, Z:0
# frame: 135
# largest_face index is 0 in 2 faces
# Y:-179, X:-54, Z:0
# frame: 136
# largest_face index is 0 in 2 faces
# Y:-177, X:-55, Z:0
# frame: 137
# largest_face index is 0 in 2 faces
# Y:-178, X:-54, Z:0
# frame: 138
# largest_face index is 0 in 2 faces
# Y:-179, X:-53, Z:0
# frame: 139
# largest_face index is 0 in 2 faces
# Y:-178, X:-53, Z:0
# frame: 140
# largest_face index is 0 in 2 faces
# Y:-176, X:-53, Z:-1
# frame: 141
# largest_face index is 0 in 2 faces
# Y:-178, X:-54, Z:1
# frame: 142
# Y:-178, X:-53, Z:1
# frame: 143
# largest_face index is 0 in 2 faces
# Y:-179, X:-54, Z:1
# frame: 144
# Y:-177, X:-51, Z:0
# frame: 145
# Y:175, X:-52, Z:4
# frame: 146
# Y:177, X:-54, Z:2
# frame: 147
# Y:-178, X:-51, Z:0
# frame: 148
# Y:-179, X:-51, Z:1
# frame: 149
# Y:-179, X:-51, Z:1
# frame: 150
# Y:-177, X:-52, Z:0
# frame: 151
# Y:-178, X:-53, Z:1
# frame: 152
# Y:-179, X:-53, Z:2
# frame: 153
# Y:178, X:-52, Z:2
# frame: 154
# Y:179, X:-52, Z:1
# frame: 155
# Y:176, X:-50, Z:3
# frame: 156
# Y:179, X:-51, Z:2
# frame: 157
# Y:177, X:-50, Z:2
# frame: 158
# Y:179, X:-51, Z:0
# frame: 159
# Y:-179, X:-53, Z:0
# frame: 160
# Y:-179, X:-53, Z:0
# frame: 161
# Y:179, X:-53, Z:1
# frame: 162
# largest_face index is 0 in 2 faces
# Y:178, X:-53, Z:0
# frame: 163
# largest_face index is 0 in 2 faces
# Y:177, X:-52, Z:0
# frame: 164
# Y:175, X:-53, Z:1
# frame: 165
# largest_face index is 0 in 2 faces
# Y:179, X:-54, Z:0
# frame: 166
# Y:176, X:-53, Z:2
# frame: 167
# Y:177, X:-54, Z:2
# frame: 168
# Y:176, X:-52, Z:3
# frame: 169
# Y:178, X:-49, Z:3
# frame: 170
# largest_face index is 0 in 2 faces
# Y:-179, X:-43, Z:2
# frame: 171
# largest_face index is 0 in 2 faces
# Y:-176, X:-49, Z:-5
# frame: 172
# Y:174, X:-57, Z:2
# frame: 173
# Y:167, X:-56, Z:7
# frame: 174
# Y:173, X:-58, Z:3
# frame: 175
# Y:175, X:-58, Z:2
# frame: 176
# Y:174, X:-60, Z:3
# frame: 177
# Y:173, X:-60, Z:4
# frame: 178
# Y:175, X:-60, Z:2
# frame: 179
# largest_face index is 0 in 2 faces
# Y:173, X:-61, Z:4
# frame: 180
# largest_face index is 0 in 2 faces
# Y:174, X:-57, Z:3
# frame: 181
# largest_face index is 0 in 2 faces
# Y:174, X:-59, Z:3
# frame: 182
# Y:168, X:-59, Z:7
# frame: 183
# Y:166, X:-57, Z:8
# frame: 184
# Y:167, X:-59, Z:8
# frame: 185
# Y:169, X:-58, Z:7
# frame: 186
# Y:169, X:-58, Z:7
# frame: 187
# largest_face index is 0 in 2 faces
# Y:168, X:-59, Z:9
# frame: 188
# Y:168, X:-59, Z:8
# frame: 189
# Y:166, X:-59, Z:10
# frame: 190
# Y:164, X:-51, Z:13
# frame: 191
# Y:166, X:-52, Z:14
# frame: 192
# Y:165, X:-53, Z:14
# frame: 193
# Y:167, X:-54, Z:15
# frame: 194
# Y:169, X:-54, Z:12
# frame: 195
# Y:164, X:-54, Z:13
# frame: 196
# largest_face index is 0 in 2 faces
# Y:174, X:-52, Z:6
# frame: 197
# Y:170, X:-52, Z:8
# frame: 198
# Y:172, X:-53, Z:6
# frame: 199
# Y:171, X:-50, Z:4
# frame: 200
# Y:172, X:-50, Z:3
# frame: 201
# Y:173, X:-49, Z:2
# frame: 202
# Y:158, X:-53, Z:15
# frame: 203
# Y:156, X:-55, Z:17
# frame: 204
# Y:157, X:-54, Z:16
# frame: 205
# Y:156, X:-55, Z:18
# frame: 206
# Y:157, X:-56, Z:16
# frame: 207
# Y:155, X:-54, Z:16
# frame: 208
# Y:154, X:-54, Z:16
# frame: 209
# Y:156, X:-55, Z:16
# frame: 210
# Y:160, X:-54, Z:13
# frame: 211
# Y:158, X:-55, Z:15
# frame: 212
# Y:157, X:-56, Z:15
# frame: 213
# Y:158, X:-54, Z:13
# frame: 214
# Y:162, X:-53, Z:11
# frame: 215
# Y:168, X:-50, Z:5
# frame: 216
# Y:163, X:-52, Z:8
# frame: 217
# Y:170, X:-50, Z:4
# frame: 218
# Y:169, X:-50, Z:3
# frame: 219
# Y:169, X:-48, Z:3
# frame: 220
# Y:170, X:-52, Z:3
# frame: 221
# Y:171, X:-51, Z:3
# frame: 222
# Y:169, X:-53, Z:4
# frame: 223
# Y:171, X:-53, Z:5
# frame: 224
# Y:152, X:-51, Z:16
# frame: 225
# Y:156, X:-51, Z:12
# frame: 226
# Y:156, X:-52, Z:12
# frame: 227
# Y:156, X:-53, Z:13
# frame: 228
# Y:156, X:-54, Z:14
# frame: 229
# Y:156, X:-52, Z:13
# frame: 230
# Y:160, X:-52, Z:10
# frame: 231
# Y:151, X:-51, Z:14
# frame: 232
# Y:154, X:-51, Z:14
# frame: 233
# Y:152, X:-52, Z:14
# frame: 234
# Y:153, X:-52, Z:14
# frame: 235
# Y:151, X:-52, Z:15
# frame: 236
# Y:158, X:-53, Z:12
# frame: 237
# Y:152, X:-52, Z:17
# frame: 238
# Y:156, X:-54, Z:14
# frame: 239
# Y:155, X:-52, Z:13
# frame: 240
# Y:160, X:-52, Z:12
# frame: 241
# Y:155, X:-51, Z:15
# frame: 242
# Y:154, X:-50, Z:18
# Y:167, X:-45, Z:5
# frame: 373
# Y:170, X:-53, Z:2
# frame: 374
# largest_face index is 0 in 2 faces
# Y:167, X:-45, Z:4
# frame: 375
# Y:163, X:-40, Z:4
# frame: 376
# Y:166, X:-43, Z:3
# frame: 377
# largest_face index is 0 in 2 faces
# Y:166, X:-47, Z:3
# frame: 378
# largest_face index is 0 in 2 faces
# Y:166, X:-52, Z:3
# frame: 379
# largest_face index is 1 in 2 faces
# Y:164, X:-51, Z:4
# frame: 380
# Y:165, X:-50, Z:3
# frame: 381
# Y:167, X:-49, Z:2
# frame: 382
# largest_face index is 1 in 2 faces
# Y:163, X:-49, Z:5
# frame: 383
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# largest_face index is 1 in 2 faces
# Y:162, X:-54, Z:5
# frame: 386
# Y:-164, X:54, Z:-1
# frame: 387
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-164, X:54, Z:0
# frame: 390
# Y:-162, X:55, Z:0
# frame: 391
# Y:-162, X:57, Z:1
# frame: 392
# Y:-161, X:56, Z:1
# frame: 393
# Y:-164, X:54, Z:0
# frame: 394
# Y:-163, X:56, Z:0
# frame: 395
# Y:-162, X:55, Z:1
# frame: 396
# Y:-160, X:56, Z:3
# frame: 397
# Y:-162, X:53, Z:0
# frame: 398
# Y:-162, X:56, Z:0
# frame: 399
# Y:-163, X:57, Z:0
# frame: 400
# Y:-160, X:54, Z:0
# frame: 401
# largest_face index is 0 in 2 faces
# Y:172, X:-64, Z:-1
# frame: 402
# largest_face index is 1 in 2 faces
# Y:172, X:-62, Z:-1
# frame: 403
# largest_face index is 1 in 2 faces
# Y:172, X:-64, Z:-1
# frame: 404
# Y:174, X:-63, Z:-3
# frame: 405
# largest_face index is 1 in 2 faces
# Y:173, X:-62, Z:-3
# frame: 406
# largest_face index is 0 in 2 faces
# Y:173, X:-63, Z:-3
# frame: 407
# largest_face index is 1 in 2 faces
# Y:173, X:-63, Z:-3
# frame: 408
# largest_face index is 1 in 2 faces
# Y:173, X:-61, Z:-2
# frame: 409
# Y:-164, X:48, Z:0
# frame: 410
# Y:-170, X:36, Z:-4
# frame: 411
# Y:-162, X:57, Z:1
# frame: 412
# Y:-165, X:56, Z:0
# frame: 413
# Y:-162, X:59, Z:1
# frame: 414
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-165, X:62, Z:-1
# frame: 421
# Y:-162, X:55, Z:-1
# frame: 422
# Y:-166, X:60, Z:-2
# frame: 423
# Y:-165, X:58, Z:-2
# frame: 424
# Y:-165, X:59, Z:-2
# frame: 425
# Y:-163, X:58, Z:-1
# frame: 426
# ERROR: found no face
# get_image_points failed
# Y:-167, X:59, Z:-3
# frame: 428
# Y:-165, X:60, Z:-4
# frame: 429
# Y:-166, X:58, Z:-4
# frame: 620
# Y:167, X:64, Z:-27
# frame: 621
# Y:167, X:64, Z:-29
# frame: 622
# Y:168, X:63, Z:-30
# frame: 623
# Y:169, X:61, Z:-28
# frame: 624
# Y:170, X:61, Z:-26
# frame: 625
# Y:179, X:55, Z:-18
# frame: 626
# Y:168, X:65, Z:-28
# frame: 627
# Y:169, X:63, Z:-27
# frame: 628
# Y:171, X:62, Z:-24
# frame: 629
# largest_face index is 1 in 2 faces
# Y:171, X:64, Z:-25
# frame: 630
# Y:160, X:49, Z:-7
# frame: 631
# ERROR: found no face
# get_image_points failed
# Y:175, X:60, Z:-22
# frame: 633
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-172, X:66, Z:-9
# frame: 644
# ERROR: found no face
# get_image_points failed
# Y:-173, X:67, Z:-10
# frame: 646
# Y:-174, X:65, Z:-12
# frame: 647
# Y:-175, X:64, Z:-14
# frame: 648
# Y:-176, X:65, Z:-13
# frame: 649
# Y:-178, X:62, Z:-17
# frame: 650
# Y:-177, X:58, Z:-16
# frame: 651
# ERROR: found no face
# get_image_points failed
# Y:-173, X:58, Z:-15
# frame: 653
# Y:-179, X:62, Z:-19
# frame: 654
# Y:-178, X:58, Z:-20
# frame: 655
# Y:-174, X:56, Z:-17
# frame: 656
# Y:-171, X:60, Z:-12
# frame: 657
# Y:-177, X:63, Z:-17
# frame: 658
# Y:-173, X:63, Z:-12
# frame: 659
# Y:-171, X:60, Z:-12
# frame: 660
# largest_face index is 0 in 2 faces
# Y:-167, X:68, Z:-5
# frame: 661
# Y:-167, X:63, Z:-5
# frame: 662
# Y:-163, X:62, Z:-3
# frame: 663
# Y:-161, X:62, Z:-1
# frame: 664
# Y:-164, X:62, Z:-3
# frame: 665
# Y:-164, X:64, Z:-2
# frame: 666
# largest_face index is 0 in 2 faces
# Y:-165, X:62, Z:-3
# frame: 667
# largest_face index is 0 in 2 faces
# Y:-163, X:66, Z:-3
# frame: 668
# largest_face index is 0 in 2 faces
# Y:-166, X:64, Z:-7
# frame: 669
# Y:-167, X:62, Z:-7
# frame: 670
# Y:-164, X:60, Z:-5
# frame: 671
# Y:-163, X:63, Z:-3
# frame: 672
# Y:-166, X:62, Z:-5
# frame: 673
# Y:-160, X:62, Z:-1
# frame: 674
# Y:-153, X:55, Z:3
# frame: 675
# Y:-167, X:9, Z:-9
# frame: 676
# Y:-163, X:65, Z:-2
# frame: 677
# Y:-162, X:63, Z:-1
# frame: 678
# Y:-167, X:-2, Z:-12
# frame: 679
# Y:-155, X:58, Z:1
# frame: 680
# Y:-158, X:60, Z:0
# frame: 681
# Y:-158, X:57, Z:-1
# frame: 682
# Y:-164, X:64, Z:-5
# frame: 683
# Y:-164, X:65, Z:-4
# frame: 684
# Y:-164, X:65, Z:-4
# frame: 685
# Y:-158, X:55, Z:-1
# frame: 686
# Y:-156, X:57, Z:0
# frame: 687
# Y:-166, X:-15, Z:-17
# frame: 688
# Y:-165, X:66, Z:-5
# frame: 689
# Y:-165, X:64, Z:-4
# frame: 690
# Y:-167, X:65, Z:-8
# frame: 691
# Y:-167, X:66, Z:-8
# frame: 692
# Y:-159, X:58, Z:-1
# frame: 693
# ERROR: found no face
# get_image_points failed
# Y:-164, X:65, Z:-4
# frame: 695
# Y:-163, X:61, Z:-6
# frame: 696
# Y:-165, X:63, Z:-6
# frame: 697
# largest_face index is 0 in 2 faces
# Y:-164, X:63, Z:-5
# frame: 698
# Y:-163, X:64, Z:-4
# frame: 699
# Y:-164, X:64, Z:-5
# frame: 700
# Y:-163, X:66, Z:-4
# frame: 701
# largest_face index is 0 in 2 faces
# Y:-163, X:64, Z:-4
# frame: 702
# largest_face index is 0 in 2 faces
# Y:-165, X:64, Z:-5
# frame: 703
# Y:-165, X:66, Z:-6
# frame: 704
# Y:-167, X:66, Z:-7
# frame: 705
# Y:-168, X:62, Z:-9
# frame: 706
# Y:-167, X:62, Z:-8
# frame: 707
# Y:-169, X:62, Z:-9
# frame: 708
# Y:-165, X:64, Z:-5
# frame: 709
# Y:-166, X:63, Z:-7
# frame: 710
# Y:-167, X:64, Z:-7
# frame: 711
# Y:-168, X:64, Z:-8
# frame: 712
# Y:-170, X:63, Z:-11
# frame: 713
# largest_face index is 0 in 2 faces
# Y:-165, X:59, Z:-6
# frame: 714
# largest_face index is 0 in 2 faces
# Y:-168, X:57, Z:-8
# frame: 715
# Y:-164, X:60, Z:-7
# frame: 716
# Y:-165, X:57, Z:-7
# frame: 717
# Y:-163, X:61, Z:-5
# frame: 718
# Y:-167, X:-6, Z:-16
# frame: 719
# Y:-171, X:63, Z:-11
# frame: 720
# Y:-167, X:63, Z:-7
# frame: 721
# Y:-167, X:64, Z:-7
# frame: 722
# Y:-167, X:65, Z:-7
# frame: 723
# Y:-169, X:62, Z:-8
# frame: 724
# Y:-168, X:64, Z:-9
# frame: 725
# Y:-171, X:64, Z:-10
# frame: 726
# Y:-161, X:57, Z:-4
# frame: 727
# Y:-168, X:65, Z:-8
# frame: 728
# Y:-168, X:65, Z:-8
# frame: 729
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-166, X:57, Z:-7
# frame: 732
# largest_face index is 1 in 2 faces
# Y:-168, X:66, Z:-6
# frame: 733
# Y:167, X:53, Z:-4
# frame: 734
# largest_face index is 1 in 2 faces
# Y:-167, X:61, Z:-8
# frame: 735
# Y:-165, X:61, Z:-6
# frame: 736
# ERROR: found no face
# get_image_points failed
# largest_face index is 1 in 2 faces
# Y:-169, X:60, Z:-9
# frame: 738
# Y:-168, X:60, Z:-8
# frame: 739
# Y:-168, X:61, Z:-10
# frame: 740
# Y:-166, X:58, Z:-8
# frame: 741
# Y:170, X:-32, Z:14
# frame: 742
# Y:169, X:53, Z:-2
# frame: 743
# largest_face index is 0 in 2 faces
# Y:-168, X:64, Z:-7
# frame: 744
# Y:-171, X:65, Z:-10
# frame: 745
# Y:-168, X:63, Z:-8
# frame: 746
# Y:-167, X:62, Z:-6
# frame: 747
# Y:-165, X:61, Z:-6
# frame: 748
# Y:-167, X:57, Z:-9
# frame: 749
# largest_face index is 0 in 2 faces
# Y:-168, X:59, Z:-8
# frame: 750
# Y:-169, X:67, Z:-9
# frame: 751
# Y:-167, X:59, Z:-8
# frame: 752
# Y:-167, X:57, Z:-8
# frame: 753
# largest_face index is 0 in 2 faces
# Y:-166, X:58, Z:-8
# frame: 754
# Y:-168, X:59, Z:-9
# frame: 755
# Y:-171, X:61, Z:-11
# frame: 756
# Y:-171, X:61, Z:-10
# frame: 757
# Y:-170, X:58, Z:-10
# frame: 758
# Y:-171, X:63, Z:-10
# frame: 759
# Y:-170, X:65, Z:-11
# frame: 760
# Y:-170, X:62, Z:-9
# frame: 761
# largest_face index is 0 in 2 faces
# Y:-171, X:61, Z:-11
# frame: 762
# Y:-169, X:63, Z:-9
# frame: 763
# Y:-170, X:63, Z:-9
# frame: 764
# Y:-170, X:64, Z:-9
# frame: 765
# Y:-171, X:63, Z:-10
# frame: 766
# Y:-170, X:63, Z:-11
# frame: 767
# Y:-171, X:65, Z:-11
# frame: 768
# Y:-173, X:63, Z:-11
# frame: 769
# Y:-172, X:65, Z:-12
# frame: 770
# Y:-173, X:63, Z:-13
# frame: 771
# Y:-173, X:64, Z:-13
# frame: 772
# Y:-170, X:66, Z:-10
# frame: 773
# Y:-169, X:66, Z:-9
# frame: 774
# Y:-172, X:66, Z:-11
# frame: 775
# Y:-171, X:66, Z:-11
# frame: 776
# Y:-171, X:64, Z:-12
# frame: 777
# Y:-170, X:65, Z:-10
# frame: 778
# Y:-171, X:60, Z:-11
# frame: 779
# Y:-169, X:61, Z:-10
# frame: 780
# Y:-168, X:57, Z:-9
# frame: 781
# Y:-171, X:59, Z:-12
# frame: 782
# Y:-171, X:61, Z:-11
# frame: 783
# Y:-172, X:62, Z:-11
# frame: 784
# largest_face index is 0 in 2 faces
# Y:-170, X:62, Z:-10
# frame: 785
# largest_face index is 0 in 2 faces
# Y:-169, X:63, Z:-8
# frame: 786
# Y:-171, X:63, Z:-10
# frame: 787
# Y:-172, X:63, Z:-11
# frame: 788
# largest_face index is 0 in 2 faces
# Y:-172, X:62, Z:-11
# frame: 789
# largest_face index is 0 in 2 faces
# Y:-171, X:62, Z:-10
# frame: 790
# Y:-170, X:63, Z:-10
# frame: 791
# Y:-171, X:64, Z:-10
# frame: 792
# Y:-171, X:59, Z:-10
# frame: 793
# Y:-170, X:60, Z:-9
# frame: 794
# Y:-171, X:62, Z:-10
# frame: 795
# Y:-169, X:-13, Z:-16
# frame: 796
# Y:-172, X:63, Z:-10
# frame: 797
# Y:-174, X:60, Z:-13
# frame: 798
# Y:-172, X:62, Z:-12
# frame: 799
# Y:-170, X:59, Z:-12
# frame: 800
# Y:-172, X:58, Z:-13
# frame: 801
# Y:-170, X:56, Z:-11
# frame: 802
# Y:-171, X:61, Z:-10
# frame: 803
# Y:178, X:20, Z:161
# frame: 804
# Y:-172, X:65, Z:-11
# frame: 805
# Y:-172, X:65, Z:-11
# frame: 806
# largest_face index is 0 in 2 faces
# Y:-172, X:65, Z:-11
# frame: 807
# Y:-179, X:17, Z:164
# frame: 808
# largest_face index is 1 in 2 faces
# Y:-171, X:62, Z:-12
# frame: 809
# largest_face index is 1 in 2 faces
# Y:-172, X:63, Z:-13
# frame: 810
# Y:-172, X:59, Z:-11
# frame: 811
# Y:-171, X:60, Z:-11
# frame: 812
# Y:-171, X:62, Z:-11
# frame: 813
# Y:-170, X:57, Z:-11
# frame: 814
# Y:-172, X:57, Z:-12
# frame: 815
# Y:-172, X:61, Z:-11
# frame: 816
# Y:-173, X:58, Z:-13
# frame: 817
# largest_face index is 0 in 2 faces
# Y:-173, X:58, Z:-13
# frame: 818
# largest_face index is 0 in 2 faces
# Y:-171, X:57, Z:-13
# frame: 819
# largest_face index is 0 in 2 faces
# Y:-171, X:57, Z:-12
# frame: 820
# Y:-169, X:55, Z:-12
# frame: 821
# largest_face index is 0 in 2 faces
# Y:-171, X:54, Z:-12
# frame: 822
# Y:-170, X:55, Z:-12
# frame: 823
# Y:-171, X:55, Z:-13
# frame: 824
# Y:-171, X:57, Z:-13
# frame: 825
# Y:-169, X:56, Z:-13
# frame: 826
# Y:-171, X:55, Z:-14
# frame: 827
# Y:-173, X:56, Z:-13
# frame: 828
# Y:-172, X:57, Z:-13
# frame: 829
# Y:-171, X:55, Z:-13
# frame: 830
# Y:-171, X:54, Z:-13
# frame: 831
# Y:-171, X:52, Z:-13
# frame: 832
# Y:-171, X:53, Z:-13
# frame: 833
# Y:-168, X:55, Z:-11
# frame: 834
# Y:-170, X:54, Z:-12
# frame: 835
# largest_face index is 0 in 2 faces
# Y:-170, X:57, Z:-12
# frame: 836
# largest_face index is 0 in 2 faces
# Y:-172, X:59, Z:-13
# frame: 837
# largest_face index is 0 in 2 faces
# Y:-170, X:59, Z:-11
# frame: 838
# Y:-174, X:64, Z:-15
# frame: 839
# largest_face index is 1 in 2 faces
# Y:-173, X:64, Z:-14
# frame: 840
# Y:-174, X:65, Z:-13
# frame: 841
# Y:-167, X:57, Z:-8
# frame: 842
# Y:-170, X:59, Z:-10
# frame: 843
# Y:-175, X:65, Z:-14
# frame: 844
# Y:-171, X:62, Z:-11
# frame: 845
# Y:-171, X:62, Z:-9
# frame: 846
# Y:-168, X:61, Z:-8
# frame: 847
# Y:-169, X:60, Z:-9
# frame: 848
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-171, X:65, Z:-10
# frame: 851
# Y:-176, X:14, Z:166
# frame: 852
# Y:-162, X:58, Z:-4
# frame: 853
# Y:-176, X:13, Z:167
# frame: 854
# Y:-177, X:15, Z:166
# frame: 855
# Y:-168, X:-7, Z:-13
# frame: 856
# Y:-165, X:60, Z:-4
# frame: 857
# largest_face index is 0 in 2 faces
# Y:-167, X:-10, Z:-15
# frame: 858
# largest_face index is 1 in 2 faces
# Y:-168, X:63, Z:-7
# frame: 859
# Y:163, X:53, Z:-6
# frame: 860
# Y:163, X:49, Z:-4
# frame: 861
# largest_face index is 1 in 2 faces
# Y:-167, X:67, Z:-5
# frame: 862
# largest_face index is 1 in 2 faces
# Y:-166, X:67, Z:-4
# frame: 863
# largest_face index is 0 in 2 faces
# Y:-166, X:70, Z:-2
# frame: 864
# Y:-169, X:68, Z:-5
# frame: 865
# Y:-167, X:67, Z:-4
# frame: 866
# Y:-168, X:68, Z:-3
# frame: 867
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-163, X:67, Z:0
# frame: 871
# Y:-168, X:68, Z:-5
# frame: 872
# Y:-165, X:69, Z:-4
# frame: 873
# Y:-165, X:68, Z:-4
# frame: 874
# Y:-166, X:65, Z:-4
# frame: 875
# Y:-166, X:66, Z:-3
# frame: 876
# Y:-161, X:65, Z:0
# frame: 877
# Y:-159, X:67, Z:0
# frame: 878
# Y:-161, X:70, Z:0
# frame: 879
# Y:-162, X:69, Z:-1
# frame: 880
# Y:-161, X:67, Z:-1
# frame: 881
# Y:-159, X:68, Z:0
# frame: 882
# Y:-160, X:69, Z:0
# frame: 883
# Y:-162, X:69, Z:0
# frame: 884
# Y:-163, X:69, Z:-1
# frame: 885
# Y:-161, X:68, Z:0
# frame: 886
# Y:-162, X:67, Z:0
# frame: 887
# Y:-160, X:68, Z:1
# frame: 888
# Y:-162, X:68, Z:0
# frame: 889
# Y:-160, X:67, Z:3
# frame: 890
# largest_face index is 0 in 2 faces
# Y:-157, X:70, Z:6
# frame: 891
# largest_face index is 0 in 2 faces
# Y:-160, X:68, Z:1
# frame: 892
# Y:-161, X:68, Z:3
# frame: 893
# Y:-160, X:70, Z:2
# frame: 894
# Y:-158, X:68, Z:4
# frame: 895
# largest_face index is 1 in 2 faces
# Y:-160, X:66, Z:3
# frame: 896
# largest_face index is 0 in 2 faces
# Y:-161, X:65, Z:2
# frame: 897
# largest_face index is 0 in 2 faces
# Y:-161, X:67, Z:1
# frame: 898
# Y:-161, X:66, Z:3
# frame: 899
# Y:-161, X:69, Z:4
# frame: 900
# largest_face index is 0 in 2 faces
# Y:-165, X:68, Z:0
# frame: 901
# largest_face index is 1 in 2 faces
# Y:-164, X:68, Z:0
# frame: 902
# largest_face index is 0 in 2 faces
# Y:-163, X:63, Z:0
# frame: 903
# largest_face index is 0 in 2 faces
# Y:-163, X:63, Z:0
# frame: 904
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-160, X:66, Z:3
# frame: 907
# largest_face index is 0 in 2 faces
# Y:-159, X:68, Z:3
# frame: 908
# largest_face index is 0 in 2 faces
# Y:-157, X:69, Z:5
# frame: 909
# largest_face index is 0 in 2 faces
# Y:-159, X:69, Z:4
# frame: 910
# largest_face index is 0 in 2 faces
# Y:-158, X:66, Z:4
# frame: 911
# Y:-159, X:64, Z:3
# frame: 912
# largest_face index is 0 in 2 faces
# Y:-157, X:67, Z:5
# frame: 913
# Y:-157, X:63, Z:5
# frame: 914
# largest_face index is 1 in 2 faces
# Y:-160, X:61, Z:1
# frame: 915
# largest_face index is 1 in 2 faces
# Y:-159, X:67, Z:3
# frame: 916
# largest_face index is 1 in 2 faces
# Y:-159, X:65, Z:2
# frame: 917
# largest_face index is 1 in 2 faces
# Y:-157, X:64, Z:4
# frame: 918
# largest_face index is 1 in 2 faces
# Y:-159, X:63, Z:2
# frame: 919
# largest_face index is 1 in 2 faces
# Y:-159, X:63, Z:2
# frame: 920
# largest_face index is 1 in 2 faces
# Y:-159, X:63, Z:2
# frame: 921
# largest_face index is 1 in 2 faces
# Y:-159, X:64, Z:3
# frame: 922
# largest_face index is 1 in 2 faces
# Y:-158, X:63, Z:2
# frame: 923
# Y:160, X:42, Z:-20
# frame: 924
# ERROR: found no face
# get_image_points failed
# Y:158, X:49, Z:-27
# frame: 926
# largest_face index is 1 in 2 faces
# Y:-156, X:64, Z:3
# frame: 927
# largest_face index is 1 in 2 faces
# Y:-155, X:65, Z:4
# frame: 928
# Y:158, X:37, Z:-19
# frame: 929
# Y:-154, X:63, Z:5
# frame: 930
# largest_face index is 0 in 2 faces
# Y:-155, X:63, Z:5
# frame: 931
# largest_face index is 0 in 2 faces
# Y:-156, X:64, Z:4
# frame: 932
# largest_face index is 0 in 2 faces
# Y:-157, X:68, Z:4
# frame: 933
# Y:-156, X:65, Z:4
# frame: 934
# Y:-157, X:69, Z:4
# frame: 935
# Y:-158, X:65, Z:3
# frame: 936
# Y:-157, X:67, Z:5
# frame: 937
# Y:-157, X:67, Z:3
# frame: 938
# Y:-155, X:65, Z:5
# frame: 939
# Y:-155, X:68, Z:6
# frame: 940
# Y:-153, X:70, Z:9
# frame: 941
# Y:-156, X:70, Z:6
# frame: 942
# Y:-155, X:70, Z:6
# frame: 943
# Y:-157, X:70, Z:4
# frame: 944
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:178, X:24, Z:166
# frame: 951
# Y:-166, X:70, Z:-3
# frame: 952
# Y:-169, X:70, Z:-3
# frame: 953
# Y:-162, X:59, Z:0
# frame: 954
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-171, X:63, Z:-9
# frame: 959
# ERROR: found no face
# get_image_points failed
# Y:-173, X:65, Z:-8
# frame: 961
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-172, X:66, Z:-8
# frame: 964
# Y:-174, X:67, Z:-10
# frame: 965
# ERROR: found no face
# get_image_points failed
# Y:-170, X:63, Z:-6
# frame: 967
# Y:-176, X:18, Z:169
# frame: 968
# Y:-172, X:63, Z:-7
# frame: 969
# ERROR: found no face
# get_image_points failed
# Y:-179, X:23, Z:170
# frame: 971
# Y:-177, X:23, Z:169
# frame: 972
# Y:-175, X:20, Z:169
# frame: 973
# ERROR: found no face
# get_image_points failed
# Y:-178, X:23, Z:169
# frame: 975
# largest_face index is 1 in 2 faces
# Y:170, X:-54, Z:-1
# frame: 976
# Y:-178, X:22, Z:168
# frame: 977
# Y:-178, X:22, Z:168
# frame: 978
# Y:-178, X:23, Z:168
# frame: 979
# Y:-171, X:68, Z:-8
# frame: 980
# Y:-176, X:68, Z:-10
# frame: 981
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-173, X:18, Z:171
# frame: 985
# largest_face index is 0 in 2 faces
# Y:-175, X:66, Z:-9
# frame: 986
# Y:-176, X:23, Z:169
# frame: 987
# largest_face index is 0 in 2 faces
# Y:-178, X:67, Z:-11
# frame: 988
# Y:160, X:37, Z:-33
# frame: 989
# Y:158, X:18, Z:-23
# frame: 990
# Y:-176, X:21, Z:174
# frame: 991
# Y:-174, X:22, Z:171
# frame: 992
# largest_face index is 0 in 2 faces
# Y:-178, X:65, Z:-11
# frame: 993
# largest_face index is 1 in 2 faces
# Y:-177, X:65, Z:-11
# frame: 994
# largest_face index is 0 in 2 faces
# Y:-178, X:64, Z:-11
# frame: 995
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-176, X:50, Z:-10
# frame: 998
# Y:-176, X:61, Z:-11
# frame: 999
# Y:-175, X:54, Z:-11
# frame: 1000
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-173, X:52, Z:-10
# frame: 1004
# Y:-177, X:45, Z:-11
# frame: 1005
# ERROR: found no face
# get_image_points failed
# Y:-174, X:48, Z:-10
# frame: 1007
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-169, X:60, Z:-9
# frame: 1012
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-165, X:63, Z:-6
# frame: 1016
# ERROR: found no face
# get_image_points failed
# Y:-164, X:65, Z:-4
# frame: 1018
# Y:-163, X:63, Z:-5
# frame: 1019
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-160, X:59, Z:-5
# frame: 1022
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-158, X:61, Z:-2
# frame: 1025
# ERROR: found no face
# get_image_points failed
# Y:-157, X:57, Z:-2
# frame: 1027
# Y:-154, X:57, Z:-2
# frame: 1028
# Y:-157, X:57, Z:-3
# frame: 1029
# Y:-154, X:59, Z:0
# frame: 1030
# Y:-156, X:52, Z:-3
# frame: 1031
# Y:-156, X:60, Z:0
# frame: 1032
# ERROR: found no face
# get_image_points failed
# Y:-152, X:57, Z:1
# frame: 1034
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-151, X:57, Z:2
# frame: 1037
# Y:-151, X:56, Z:1
# frame: 1038
# Y:-152, X:54, Z:0
# frame: 1039
# Y:-153, X:53, Z:0
# frame: 1040
# Y:-150, X:58, Z:3
# frame: 1041
# Y:174, X:16, Z:162
# frame: 1042
# Y:-154, X:56, Z:0
# frame: 1043
# Y:-153, X:53, Z:0
# frame: 1044
# Y:-151, X:56, Z:3
# frame: 1045
# Y:-149, X:57, Z:5
# frame: 1046
# Y:176, X:13, Z:164
# frame: 1047
# Y:-150, X:53, Z:3
# frame: 1048
# Y:-148, X:54, Z:5
# frame: 1049
# Y:-151, X:51, Z:2
# frame: 1050
# Y:-146, X:60, Z:9
# frame: 1051
# Y:-151, X:52, Z:1
# frame: 1052
# Y:-154, X:51, Z:0
# frame: 1053
# Y:-155, X:53, Z:0
# frame: 1054
# Y:-153, X:54, Z:3
# frame: 1055
# Y:-149, X:56, Z:4
# frame: 1056
# Y:-152, X:55, Z:2
# frame: 1057
# Y:-149, X:56, Z:4
# frame: 1058
# Y:-150, X:56, Z:4
# frame: 1059
# Y:-150, X:57, Z:6
# frame: 1060
# Y:-146, X:47, Z:4
# frame: 1061
# Y:179, X:10, Z:168
# frame: 1062
# ERROR: found no face
# get_image_points failed
# Y:-153, X:52, Z:2
# frame: 1064
# Y:-153, X:52, Z:2
# frame: 1065
# ERROR: found no face
# get_image_points failed
# Y:-152, X:53, Z:2
# frame: 1067
# Y:-150, X:54, Z:3
# frame: 1068
# Y:-151, X:53, Z:2
# frame: 1069
# Y:-152, X:54, Z:1
# frame: 1070
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-151, X:52, Z:2
# frame: 1073
# Y:-150, X:55, Z:3
# frame: 1074
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-155, X:50, Z:0
# frame: 1079
# largest_face index is 0 in 2 faces
# Y:-175, X:-60, Z:-9
# frame: 1080
# largest_face index is 0 in 2 faces
# Y:-178, X:-59, Z:-8
# frame: 1081
# largest_face index is 1 in 2 faces
# Y:179, X:-57, Z:-4
# frame: 1082
# largest_face index is 0 in 2 faces
# Y:-176, X:-57, Z:-8
# frame: 1083
# largest_face index is 0 in 2 faces
# Y:178, X:-58, Z:-5
# frame: 1084
# largest_face index is 0 in 2 faces
# Y:-179, X:-59, Z:-6
# frame: 1085
# largest_face index is 0 in 2 faces
# Y:176, X:-58, Z:-3
# frame: 1086
# largest_face index is 0 in 2 faces
# Y:177, X:-57, Z:-3
# frame: 1087
# largest_face index is 0 in 2 faces
# Y:176, X:-58, Z:-4
# frame: 1088
# largest_face index is 0 in 2 faces
# Y:176, X:-57, Z:-3
# frame: 1089
# Y:176, X:-60, Z:-4
# frame: 1090
# Y:175, X:-58, Z:-2
# frame: 1091
# Y:179, X:-58, Z:-1
# frame: 1092
# Y:168, X:-57, Z:3
# frame: 1093
# Y:-173, X:-58, Z:-6
# frame: 1094
# Y:-172, X:-56, Z:-8
# frame: 1095
# Y:177, X:-57, Z:-1
# frame: 1096
# Y:-170, X:-56, Z:-8
# frame: 1097
# Y:-178, X:-55, Z:-3
# frame: 1098
# Y:170, X:-56, Z:1
# frame: 1099
# Y:174, X:-59, Z:-1
# frame: 1100
# Y:175, X:-59, Z:-1
# frame: 1101
# Y:158, X:-24, Z:16
# frame: 1102
# largest_face index is 0 in 2 faces
# Y:174, X:-58, Z:0
# frame: 1103
# largest_face index is 0 in 2 faces
# Y:176, X:-57, Z:-2
# frame: 1104
# largest_face index is 0 in 2 faces
# Y:162, X:-43, Z:8
# frame: 1105
# largest_face index is 0 in 2 faces
# Y:-179, X:-52, Z:-4
# frame: 1106
# largest_face index is 0 in 2 faces
# Y:166, X:-50, Z:6
# frame: 1107
# Y:170, X:-55, Z:3
# frame: 1108
# largest_face index is 0 in 2 faces
# Y:166, X:-54, Z:7
# frame: 1109
# largest_face index is 0 in 2 faces
# Y:168, X:-53, Z:7
# frame: 1110
# largest_face index is 0 in 2 faces
# Y:156, X:-23, Z:17
# frame: 1111
# Y:165, X:-38, Z:7
# frame: 1112
# largest_face index is 0 in 2 faces
# Y:171, X:-53, Z:3
# frame: 1113
# largest_face index is 0 in 2 faces
# Y:172, X:-52, Z:4
# frame: 1114
# largest_face index is 0 in 2 faces
# Y:156, X:-11, Z:10
# frame: 1115
# largest_face index is 0 in 2 faces
# Y:171, X:-40, Z:5
# frame: 1116
# Y:169, X:-45, Z:5
# frame: 1117
# largest_face index is 0 in 2 faces
# Y:159, X:-8, Z:4
# frame: 1118
# Y:171, X:-26, Z:5
# frame: 1119
# Y:176, X:-47, Z:3
# frame: 1120
# Y:178, X:-40, Z:0
# frame: 1121
# Y:179, X:-40, Z:-1
# frame: 1122
# Y:167, X:-45, Z:6
# frame: 1123
# Y:-178, X:-38, Z:-3
# frame: 1124
# Y:172, X:-43, Z:1
# frame: 1125
# Y:173, X:-40, Z:1
# frame: 1126
# Y:171, X:-40, Z:2
# frame: 1127
# Y:174, X:-40, Z:0
# frame: 1128
# Y:174, X:-38, Z:1
# frame: 1129
# Y:174, X:-37, Z:1
# frame: 1130
# Y:174, X:-35, Z:0
# frame: 1131
# Y:172, X:-36, Z:3
# frame: 1132
# Y:174, X:-35, Z:1
# frame: 1133
# Y:175, X:-36, Z:0
# frame: 1134
# Y:176, X:-35, Z:0
# frame: 1135
# Y:178, X:-34, Z:0
# frame: 1136
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# ERROR: found no face
# get_image_points failed
# Y:-173, X:-44, Z:-5
# frame: 1140
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-6ff807d4731d> in <module>()
#     177
#     178         ret, im = camera.read()
# --> 179         im = im[269: 795, 337: 1000]
#     180         #print(ret,im)
#     181         if not ret:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# for line in open("C:/Users/lll/Documents/hz/conda/Eye_detection/head_example_Take_001.txt"):
#     for num in line:
#         print(num)
file=open('C:/Users/lll/Documents/hz/conda/Eye_detection/ikari30_Take_001.txt','r')
with open('origin_iraki_frame.csv', mode='w',newline ='') as csvfile:
    fieldnames = ['Z', 'X', 'Y']
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    result=list()
    for c in file.readlines():
        c_array=c.split(" ")
#       result.append(c_array[0])
        print(c_array[3])
        writer.writerow({'Z': c_array[3], 'X':c_array[4], 'Y': c_array[5]})
#print(result)
# Out:
# -35.8699
# -41.1945
# -45.4707
# -48.5138
# -50.4047
# -51.3973
# -51.7709
# -51.8715
# -51.966
# -52.0605
# -51.9601
# -51.6877
# -51.5118
# -51.7301
# -52.2023
# -52.5849
# -52.6669
# -52.5947
# -52.6583
# -52.9903
# -53.4067
# -53.5357
# -53.0384
# -51.8628
# -50.1943
# -48.1832
# -45.7878
# -43.1419
# -40.8466
# -39.6558
# -39.9202
# -41.4505
# -43.828
# -46.5997
# -49.3357
# -51.6884
# -53.4609
# -54.7486
# -55.6845
# -56.4533
# -57.05
# -57.3843
# -57.6097
# -57.9854
# -58.6003
# -59.3155
# -60.0199
# -60.9386
# -62.4614
# -64.7418
# -67.2226
# -68.9454
# -69.223
# -68.105
# -66.1193
# -63.7758
# -61.3036
# -58.6493
# -55.753
# -52.8099
# -50.2657
# -48.1536
# -45.8182
# -42.5206
# -37.9964
# -32.6734
# -27.1639
# -21.7965
# -16.54
# -11.1417
# -5.12335
# 1.82415
# 9.11063
# 15.363
# 19.6883
# 22.4652
# 24.6571
# 26.8874
# 29.2274
# 31.6675
# 34.1574
# 36.6078
# 38.8385
# 40.961
# 43.2085
# 45.7005
# 48.2633
# 50.6977
# 52.8968
# 54.7943
# 56.3839
# 57.6072
# 58.6984
# 59.865
# 61.1227
# 62.306
# 63.2373
# 63.9628
# 64.6831
# 65.4438
# 65.9687
# 65.912
# 65.2452
# 64.4579
# 64.173
# 64.6041
# 65.404
# 66.1549
# 66.8036
# 67.5229
# 68.3043
# 68.795
# 68.683
# 68.0879
# 67.4601
# 67.1954
# 67.2566
# 67.2197
# 66.7731
# 65.9803
# 65.1673
# 64.5566
# 64.3418
# 64.6485
# 65.3439
# 66.0722
# 66.6351
# 67.2995
# 68.5015
# 69.9965
# 71.5898
# 72.8792
# 73.8774
# 74.9966
# 76.5221
# 79.1036
# 83.5387
# 89.5096
# 95.8503
# 102.069
# 108.132
# 113.432
# 117.801
# 122.285
# 127.474
# 132.225
# 132.708
# 111.222
# 61.8397
# 45.0092
# 37.5162
# 28.0227
# 17.7402
# 10.8865
# 7.74302
# 5.84312
# 4.50559
# 5.7103
# 11.1355
# 19.649
# 27.4052
# 30.5365
# 27.9636
# 22.2707
# 16.7508
# 11.733
# 5.77267
# -1.10132
# -7.18726
# -11.0017
# -13.061
# -14.8883
# -17.424
# -20.5234
# -23.7556
# -26.7993
# -56.153
# -52.9013
# -50.0279
# -47.6113
# -45.4255
# -43.4563
# -42.1924
# -41.8541
# -42.119
# -42.5863
# -43.1229
# -43.8297
# -44.8326
# -46.01
# -47.1349
# -48.0509
# -48.7884
# -49.3989
# -49.7187
# -49.485
# -48.7984
# -47.9721
# -47.2675
# -46.6007
# -45.5204
# -43.6406
# -41.0227
# -38.2015
# -35.7281
# -33.9822
# -33.3321
# -33.9805
# -35.6508
# -37.5723
# -39.0301
# -39.6331
# -39.5532
# -39.2009
# -39.0607
# -39.3926
# -40.0305
# -40.7798
# -41.5722
# -42.4861
# -43.4892
# -44.2918
# -44.4841
# -43.9437

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import numpy as np
from scipy.interpolate import spline

def smoothing(array):
    
    len_x = 1000
    list_x = np.arange(len_x)
    joint_name = ['LeftShoulder_xp', 'LeftShoulder_yp', 'LeftShoulder_zp','LeftShoulder_zr', 'LeftShoulder_xr', 'LeftShoulder_yr']

    array = np.zeros([12,len_x])
    for i, name in enumerate(joint_name):
        array[i]=ru[name][:len_x]
    # list_x = np.arange(len_x)
    # array_RightShoulder_xr= ru['RightShoulder_xr'][:len_x]
    # array_RightForeArm_xr= ru['RightForeArm_xr'][:len_x]
    # array_RightHand_xr= ru['RightHand_xr'][:len_x]
    # array_RightArm_xr= ru['RightArm_xr'][:len_x]
    # array_RightShoulder_yr= ru['RightShoulder_yr'][:len_x]
    # array_RightForeArm_yr= ru['RightForeArm_yr'][:len_x]
    # array_RightHand_yr= ru['RightHand_yr'][:len_x]
    # array_RightArm_yr= ru['RightArm_yr'][:len_x]
    # array_RightShoulder_zr= ru['RightShoulder_zr'][:len_x]
    # array_RightForeArm_zr= ru['RightForeArm_zr'][:len_x]
    # array_RightHand_zr= ru['RightHand_zr'][:len_x]
    # array_RightArm_zr= ru['RightArm_zr'][:len_x]

    import scipy.signal as signal
    from sklearn import preprocessing

    def smoothing(joint,list_x):   
        # Local variables
        x = []
        y = []


        x_sm =list_x
        y_sm =joint

        x_smooth = np.linspace(0,1000, 80)
        y_smooth = spline(x_sm, y_sm, x_smooth)


        plt.figure(figsize=(6,1))
        plt.plot(list_x,joint)
        plt.plot(x_smooth,y_smooth)
        plt.show()
        return x_smooth,y_smooth

    def max_min(x_smooth,y_smooth):
        #print (x_smooth[signal.argrelextrema(y_smooth, np.greater)])
        #print (x_smooth[signal.argrelextrema(y_smooth, np.less)])
        #print (signal.argrelextrema(y_smooth, np.greater))
        #print (signal.argrelextrema(y_smooth, np.less))
        #plt.figure(figsize=(16,8))
        #plt.plot(x_smooth[signal.argrelextrema(y_smooth,np.greater)[0]],y_smooth[signal.argrelextrema(y_smooth, np.greater)],'o')
        #plt.plot(x_smooth[signal.argrelextrema(y_smooth,np.less)[0]],y_smooth[signal.argrelextrema(y_smooth, np.less)],'x')
        #plt.plot(x_smooth,y_smooth)
        print(signal.argrelextrema(y_smooth,np.greater)[0])
        print(signal.argrelextrema(y_smooth,np.less)[0])

        plt.show()
    def scale(joint):
        max_abs_scaler = preprocessing.MaxAbsScaler()
        scaled = max_abs_scaler.fit_transform(joint)
        return scaled
    for i,joint in enumerate(joint_name):
        #scaled = scale([array[i]])
        x_smooth,y_smooth = smoothing(array[i],list_x)
        max_min(x_smooth,y_smooth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4b735126b7ca> in <module>()
#      11 array = np.zeros([12,len_x])
#      12 for i, name in enumerate(joint_name):
# ---> 13     array[i]=ru[name][:len_x]
#      14 # list_x = np.arange(len_x)
#      15 # array_RightShoulder_xr= ru['RightShoulder_xr'][:len_x]
#
# NameError: name 'ru' is not defined

# %%
# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
# %matplotlib inline
from pandas import read_csv
import pandas as pd
orgin_head = pd.read_csv("C:/Users/lll/Documents/hz/conda/Eye_detection/data/sigisakaya_02_leftShoulder_transfer.csv")
#orgin_neck = pd.read_csv("C:/Users/lll/Documents/hz/conda/Eye_detection/data/kanashima_Neck_transfer.csv")
head = pd.read_csv("C:/Users/lll/Documents/hz/conda/Eye_detection/hadaka_sugisakaya02_gaze_ratio.csv")
#orgin_neck = pd.read_csv("C:/Users/lll/Documents/hz/conda/Eye_detection/player_ikari30_neck_frame.csv")
#head['f2Y'] = np.where(f2['Y']>=0,50,0)
plt.figure(figsize=(16,8))
#plt.plot(orgin_head["Y"], label = 'yorgin_head')
#plt.plot(head["Y"], label = 'yhead')
plt.plot(orgin_head["LeftShoulder_xp"][1000:2000]+150, label = 'Origin_Osore_LeftShoulder')#LeftShoulder_xp
#plt.plot(orgin_neck["LeftShoulder_xr"], label = 'orgin_neck')
plt.plot(head["ratio"][1000:2000]*100, label = 'Eyesight')
#plt.plot(orgin_head["Z"], label = 'zorgin_head')
#plt.plot(head["Z"], label = 'zhead')
#plt.plot(orgin_neck["X"], label = 'origin_neck')

plt.legend()
plt.show()

# %%
# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
# %matplotlib inline
from pandas import read_csv
import pandas as pd
orgin_head = pd.read_csv("C:/Users/lll/Documents/hz/conda/Eye_detection/data/kanashima_LeftShoulder_transfer.csv")
#orgin_neck = pd.read_csv("C:/Users/lll/Documents/hz/conda/Eye_detection/data/kanashima_Neck_transfer.csv")
head = pd.read_csv("C:/Users/lll/Documents/hz/conda/Eye_detection/gaze_ratio.csv")
#orgin_neck = pd.read_csv("C:/Users/lll/Documents/hz/conda/Eye_detection/player_ikari30_neck_frame.csv")
#head['f2Y'] = np.where(f2['Y']>=0,50,0)
plt.figure(figsize=(16,8))
#plt.plot(orgin_head["Y"], label = 'yorgin_head')
#plt.plot(head["Y"], label = 'yhead')
plt.plot(orgin_head["LeftShoulder_xp"], label = 'Origin_kanashima_LeftShoulderd')#LeftShoulder_xp
#plt.plot(orgin_neck["LeftShoulder_xr"], label = 'orgin_neck')
plt.plot(head["ratio"]*10, label = 'Eyesight')
#plt.plot(orgin_head["Z"], label = 'zorgin_head')
#plt.plot(head["Z"], label = 'zhead')
#plt.plot(orgin_neck["X"], label = 'origin_neck')

plt.legend()
plt.show()
