# %%
import csv
import numpy as np
# for line in open("C:/Users/lll/Documents/hz/conda/Eye_detection/head_example_Take_001.txt"):
#     for num in line:
#         print(num)
file=open('C:/Users/lll/Documents/motion/data/csv_data/Neck_Head_transfer.csv,'r')
for c in file.readlines():
    c_array=c.split(" ")
    #result.append(c_array[0])
    #print(np.shape(c_array))
    print(c_array[10],c_array[50],c_array[100],)
# Out:
#   File "<ipython-input-38-8392e5e9df4e>", line 6
#     file=open('C:/Users/lll/Documents/motion/data/csv_data/Neck_Head_transfer.csv,'r')
#                                                                                       ^
# SyntaxError: EOL while scanning string literal

# %%
import csv
# for line in open("C:/Users/lll/Documents/hz/conda/Eye_detection/head_example_Take_001.txt"):
#     for num in line:
#         print(num)
file=open('C:/Users/lll/Documents/motion/data/origin_data/Neck_Head_Take_001.txt','r')
with open('C:/Users/lll/Documents/motion/data/csv_data/Neck_Head_transfer.csv', mode='w',newline ='') as csvfile:
    fieldnames = ['Neck_xp', 'Neck_yp', 'Neck_zp','Neck_zr', 'Neck_xr', 'Neck_yr','Head_xp', 'Head_yp', 'Head_zp','Head_zr', 'Head_xr', 'Head_yr']
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    result=list()
    for c in file.readlines():
        c_array=c.split(' ')
#       result.append(c_array[0])
        #print(c_array[0])
        writer.writerow({'Neck_xp': c_array[0], 'Neck_yp':c_array[1], 'Neck_zp': c_array[2],'Neck_zr': c_array[3], 'Neck_xr':c_array[4], 'Neck_yr': c_array[5],
                        'Head_xp': c_array[6], 'Head_yp':c_array[7], 'Head_zp': c_array[8],'Head_zr': c_array[9], 'Head_xr':c_array[10], 'Head_yr': c_array[11]})
#print(result)

# %%
# import csv
# for line in open("C:/Users/lll/Documents/hz/conda/Eye_detection/head_example_Take_001.txt"):
#     for num in line:
#         print(num)
file=open('C:/Users/lll/Documents/motion/data/origin_data/LeftUpbody_Take_001.txt','r')
with open('C:/Users/lll/Documents/motion/data/csv_data/LeftUpbody_transfer.csv', mode='w',newline ='') as csvfile:
    fieldnames = ['LeftShoulder_xp', 'LeftShoulder_yp', 'LeftShoulder_zp','LeftShoulder_zr', 'LeftShoulder_xr', 'LeftShoulder_yr','LeftArm_xp', 'LeftArm_yp', 'LeftArm_zp','LeftArm_zr', 'LeftArm_xr', 'LeftArm_yr',
                'LeftForeArm_xp', 'LeftForeArm_yp', 'LeftForeArm_zp','LeftForeArm_zr', 'LeftForeArm_xr', 'LeftForeArm_yr','LeftHand_xp', 'LeftHand_yp', 'LeftHand_zp','LeftHand_zr', 'LeftHand_xr', 'LeftHand_yr']
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    result=list()
    for c in file.readlines():
        c_array=c.split(' ')
#       result.append(c_array[0])
        #print(c_array[0])
        writer.writerow({'LeftShoulder_xp': c_array[0], 'LeftShoulder_yp':c_array[1], 'LeftShoulder_zp': c_array[2],'LeftShoulder_zr': c_array[3], 'LeftShoulder_xr':c_array[4], 'LeftShoulder_yr': c_array[5],
                        'LeftArm_xp': c_array[6], 'LeftArm_yp':c_array[7], 'LeftArm_zp': c_array[8],'LeftArm_zr': c_array[9], 'LeftArm_xr':c_array[10], 'LeftArm_yr': c_array[11],
                        'LeftForeArm_xp': c_array[12], 'LeftForeArm_yp':c_array[13], 'LeftForeArm_zp': c_array[14],'LeftForeArm_zr': c_array[15], 'LeftForeArm_xr':c_array[16], 'LeftForeArm_yr': c_array[17],
                        'LeftHand_xp': c_array[18], 'LeftHand_yp':c_array[19], 'LeftHand_zp': c_array[20],'LeftHand_zr': c_array[21], 'LeftHand_xr':c_array[22], 'LeftHand_yr': c_array[23]})
#print(result)

# %%
import csv
# for line in open("C:/Users/lll/Documents/hz/conda/Eye_detection/head_example_Take_001.txt"):
#     for num in line:
#         print(num)
file=open('C:/Users/lll/Documents/motion/data/origin_data/RightUpbody_Take_001.txt','r')
with open('C:/Users/lll/Documents/motion/data/csv_data/RightUpbody_transfer.csv', mode='w',newline ='') as csvfile:
    fieldnames = ['RightShoulder_xp', 'RightShoulder_yp', 'RightShoulder_zp','RightShoulder_zr', 'RightShoulder_xr', 'RightShoulder_yr','RightArm_xp', 'RightArm_yp', 'RightArm_zp','RightArm_zr', 'RightArm_xr', 'RightArm_yr',
                'RightForeArm_xp', 'RightForeArm_yp', 'RightForeArm_zp','RightForeArm_zr', 'RightForeArm_xr', 'RightForeArm_yr','RightHand_xp', 'RightHand_yp', 'RightHand_zp','RightHand_zr', 'RightHand_xr', 'RightHand_yr']
    
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    result=list()
    for c in file.readlines():
        c_array=c.split(' ')
#       result.append(c_array[0])
        #print(c_array[0])
        writer.writerow({'RightShoulder_xp': c_array[0], 'RightShoulder_yp':c_array[1], 'RightShoulder_zp': c_array[2],'RightShoulder_zr': c_array[3], 'RightShoulder_xr':c_array[4], 'RightShoulder_yr': c_array[5],
                        'RightArm_xp': c_array[6], 'RightArm_yp':c_array[7], 'RightArm_zp': c_array[8],'RightArm_zr': c_array[9], 'RightArm_xr':c_array[10], 'RightArm_yr': c_array[11],
                        'RightForeArm_xp': c_array[12], 'RightForeArm_yp':c_array[13], 'RightForeArm_zp': c_array[14],'RightForeArm_zr': c_array[15], 'RightForeArm_xr':c_array[16], 'RightForeArm_yr': c_array[17],
                        'RightHand_xp': c_array[18], 'RightHand_yp':c_array[19], 'RightHand_zp': c_array[20],'RightHand_zr': c_array[21], 'RightHand_xr':c_array[22], 'RightHand_yr': c_array[23]})
#print(result)

# %%
import pandas as pd

# Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns; sns.set()
# %matplotlib inline
from pandas import read_csv
import pandas as pd
ru = pd.read_csv('C:/Users/lll/Documents/motion/data/csv_data/RightUpbody_transfer.csv')
nh = pd.read_csv('C:/Users/lll/Documents/motion/data/csv_data/Neck_Head_transfer.csv')                   
plt.figure(figsize=(16,8))
plt.plot(ru['RightForeArm_yr'][:1000], label = '肩ロールL')
plt.plot(ru["RightForeArm_xr"][:1000], label = '肘L')
plt.plot(ru["RightForeArm_zr"][:1000], label = '肘L')                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               
#plt.plot(nh["Head_zr"][2000:3000], label = '肘L')
#plt.plot(orgin_neck["X"], label = 'origin_neck')

plt.legend()
plt.show()

# %%
list_x = np.arange(1000)
list_y =ru['RightArm_yr'][:1000]
len(list_y)
list_x_forearm = np.arange(1000)
list_y_forearm =ru['RightForeArm_yr'][:1000]

# %%
#!/usr/bin/python

import matplotlib.pyplot as plt
import time
import numpy as np
from scipy.interpolate import spline

# Local variables
x = []
y = []

# Create a canvas to place the subgraphs
canvas = plt.figure()
rect = canvas.patch
rect.set_facecolor('white')


x_sm =list_x
y_sm =list_y

x_smooth = np.linspace(0,1000, 80)
y_smooth = spline(x_sm, y_sm, x_smooth)

# Define the matrix of 1x1 to place subplots
# Placing the plot1 on 1x1 matrix, at pos 1
sp1 = canvas.add_subplot(1,1,1, axisbg='w')
#sp1.plot(x, y, 'red', linewidth=2)
sp1.plot(x_smooth, y_smooth, 'blue', linewidth=1)

# Colorcode the tick tabs 
sp1.tick_params(axis='x', colors='red')
sp1.tick_params(axis='y', colors='red')

# Colorcode the spine of the graph
sp1.spines['bottom'].set_color('r')
sp1.spines['top'].set_color('r')
sp1.spines['left'].set_color('r')
sp1.spines['right'].set_color('r')

# Put the title and labels
sp1.set_title('matplotlib example 1', color='red')
sp1.set_xlabel('matplot x label', color='red')
sp1.set_ylabel('matplot y label', color='red')

# Show the plot/image
plt.tight_layout()
plt.grid(alpha=0.8)

plt.show()
plt.plot(list_x,list_y)
plt.show()
# Out:
# C:\Users\lll\AppData\Local\conda\conda\envs\tensorflow_gpu\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# C:\Users\lll\AppData\Local\conda\conda\envs\tensorflow_gpu\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
#!/usr/bin/python

import matplotlib.pyplot as plt
import time
import numpy as np
from scipy.interpolate import spline

# Local variables
x = []
y = []

# Create a canvas to place the subgraphs
canvas = plt.figure()
rect = canvas.patch
rect.set_facecolor('white')


x_sm_forearm =list_x_forearm
y_sm_forearm =list_y_forearm

x_smooth_forearm = np.linspace(0,1000, 80)
y_smooth_forearm = spline(x_sm_forearm, y_sm_forearm, x_smooth_forearm)

# Define the matrix of 1x1 to place subplots
# Placing the plot1 on 1x1 matrix, at pos 1
sp1 = canvas.add_subplot(1,1,1, axisbg='w')
#sp1.plot(x, y, 'red', linewidth=2)
sp1.plot(x_smooth_forearm, y_smooth_forearm, 'blue', linewidth=1)

# Colorcode the tick tabs 
sp1.tick_params(axis='x', colors='red')
sp1.tick_params(axis='y', colors='red')

# Colorcode the spine of the graph
sp1.spines['bottom'].set_color('r')
sp1.spines['top'].set_color('r')
sp1.spines['left'].set_color('r')
sp1.spines['right'].set_color('r')

# Put the title and labels
sp1.set_title('matplotlib example 1', color='red')
sp1.set_xlabel('matplot x label', color='red')
sp1.set_ylabel('matplot y label', color='red')

# Show the plot/image
plt.tight_layout()
plt.grid(alpha=0.8)

plt.show()
plt.plot(list_x_forearm,list_y_forearm)
plt.show()
# Out:
# C:\Users\lll\AppData\Local\conda\conda\envs\tensorflow_gpu\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# C:\Users\lll\AppData\Local\conda\conda\envs\tensorflow_gpu\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
from PyEMD import EMD
import numpy as np
import pylab as plt
# Define signal
t = x_smooth[31:37]
s = y_smooth[31:37]
# Execute EMD on signal
IMF = EMD().emd(s,t)
N = IMF.shape[0]+1
# Plot results
plt.subplot(N,1,1)
plt.plot(t, s, 'r')
plt.title("Input signal: $S(t)=cos(22\pi t^2) + 6t^2$")
plt.xlabel("Time [s]")
for n, imf in enumerate(IMF):
    plt.subplot(N,1,n+2)
    plt.plot(t, imf, 'g')
    plt.title("IMF "+str(n+1))
    plt.xlabel("Time [s]")
plt.tight_layout()
plt.savefig('simple_example')
plt.show()

# %%
import scipy.signal as signal

print (x_smooth[signal.argrelextrema(y_smooth, np.greater)])
print (x_smooth[signal.argrelextrema(y_smooth, np.less)])
print (signal.argrelextrema(y_smooth, np.greater))
print (signal.argrelextrema(y_smooth, np.less))
plt.figure(figsize=(16,10))
plt.plot(x_smooth[signal.argrelextrema(y_smooth,np.greater)[0]],y_smooth[signal.argrelextrema(y_smooth, np.greater)],'o')
plt.plot(x_smooth[signal.argrelextrema(y_smooth,np.less)[0]],y_smooth[signal.argrelextrema(y_smooth, np.less)],'x')
plt.plot(x_smooth,y_smooth)

plt.show()
# Out:
# [ 12.65822785  88.60759494 126.58227848 253.16455696 291.13924051
#  341.7721519  379.74683544 417.72151899 518.98734177 582.27848101
#  721.51898734 746.83544304 848.10126582 936.70886076 987.34177215]
# [ 37.97468354 101.26582278 177.21518987 265.82278481 303.79746835
#  367.08860759 392.40506329 468.35443038 531.64556962 670.88607595
#  734.17721519 797.46835443 886.07594937 974.6835443 ]
# (array([ 1,  7, 10, 20, 23, 27, 30, 33, 41, 46, 57, 59, 67, 74, 78],
#       dtype=int64),)
# (array([ 3,  8, 14, 21, 24, 29, 31, 37, 42, 53, 58, 63, 70, 77],
#       dtype=int64),)

# %%
import scipy.signal as signal

print (x_smooth_forearm[signal.argrelextrema(y_smooth_forearm, np.greater)])
print (x_smooth_forearm[signal.argrelextrema(y_smooth_forearm, np.less)])
print (signal.argrelextrema(y_smooth_forearm, np.greater))
print (signal.argrelextrema(y_smooth_forearm, np.less))
plt.figure(figsize=(16,10))
plt.plot(x_smooth_forearm[signal.argrelextrema(y_smooth_forearm,np.greater)[0]],y_smooth_forearm[signal.argrelextrema(y_smooth_forearm, np.greater)],'o')
plt.plot(x_smooth_forearm[signal.argrelextrema(y_smooth_forearm,np.less)[0]],y_smooth_forearm[signal.argrelextrema(y_smooth_forearm, np.less)],'x')
plt.plot(x_smooth_forearm,y_smooth_forearm)

plt.show()
# Out:
# [ 63.29113924 113.92405063 189.87341772 341.7721519  417.72151899
#  481.01265823 531.64556962 569.62025316 607.59493671 632.91139241
#  696.20253165 797.46835443 835.44303797 860.75949367 924.05063291
#  987.34177215]
# [ 12.65822785 101.26582278 164.55696203 303.79746835 379.74683544
#  455.69620253 506.32911392 544.30379747 582.27848101 620.25316456
#  670.88607595 721.51898734 822.78481013 848.10126582 911.39240506
#  936.70886076]
# (array([ 5,  9, 15, 27, 33, 38, 42, 45, 48, 50, 55, 63, 66, 68, 73, 78],
#       dtype=int64),)
# (array([ 1,  8, 13, 24, 30, 36, 40, 43, 46, 49, 53, 57, 65, 67, 72, 74],
#       dtype=int64),)

# %%
from PyEMD import EEMD
import numpy as np
import pylab as plt
# Define signal
t =  np.append(x_smooth[1:8],x_smooth_forearm[1:8]+(x_smooth[8]-x_smooth[1]+10))
S = np.append(y_smooth[1:8],y_smooth_forearm[1:8])
# Assign EEMD to `eemd` variable
eemd = EEMD()
# Say we want detect extrema using parabolic method
emd = eemd.EMD
emd.extrema_detection="parabol"
# Execute EEMD on S
eIMFs = eemd.eemd(S, t)
nIMFs = eIMFs.shape[0]
# Plot results
plt.figure(figsize=(12,9))
plt.subplot(nIMFs+1, 1, 1)
plt.plot(t, S, 'r')
for n in range(nIMFs):
    plt.subplot(nIMFs+1, 1, n+2)
    plt.plot(t, eIMFs[n], 'g')
    plt.ylabel("eIMF %i" %(n+1))
    plt.locator_params(axis='y', nbins=5)
plt.xlabel("Time [s]")
plt.tight_layout()
plt.savefig('eemd_example', dpi=120)
plt.show()

# %%
x_smooth[31:37]
# Out:
# array([392.40506329, 405.06329114, 417.72151899, 430.37974684,
#        443.03797468, 455.69620253])

# %%
x_smooth_forearm[30:36]+(x_smooth[37]-x_smooth[31]+10)
# Out:
# array([465.69620253, 478.35443038, 491.01265823, 503.67088608,
#        516.32911392, 528.98734177])

# %%
len(x_smooth[31:37])
# Out:
# 6

# %%
#!/usr/bin/python

import matplotlib.pyplot as plt
import time
import numpy as np
from scipy.interpolate import spline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
# %matplotlib inline
from pandas import read_csv
import pandas as pd

# Local variables
x = []
y = []


x_sm =list_x
y_sm =list_y

x_smooth = np.linspace(0,1000, 40)
y_smooth = spline(x_sm, y_sm, x_smooth)




plt.figure(figsize=(16,8))
plt.plot(list_x,list_y)
plt.plot(x_smooth,y_smooth)
plt.show()
# Out:
# C:\Users\lll\AppData\Local\conda\conda\envs\tensorflow_gpu\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
