# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
 
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
import pandas as pd
cap = pd.read_csv("/Users/houzhuo/Downloads/capdata3.csv")
robot    = pd.read_csv("/Users/houzhuo/Downloads/robot.csv")
full = pd.concat([cap,robot],axis=1)
full.head()
# Out:
#    No        1        2        3        4        5        6        7        8  \
# 0   1 -70.2093  77.6512 -2.40005 -30.6520 -70.7097 -18.5101 -1.48789  6.43077
# 1   2 -70.2093  77.6512 -2.40005 -30.0076 -70.6074 -17.7873 -1.51620  6.45095
# 2   3 -70.2093  77.6512 -2.40005 -29.4269 -70.5241 -17.1182 -1.53064  6.46612
# 3   4 -70.2093  77.6512 -2.40005 -28.9343 -70.4591 -16.5383 -1.52306  6.47134
# 4   5 -70.2093  77.6512 -2.40005 -28.3700 -70.3946 -15.9114 -1.51531  6.47130
#
#          9        ...          Shoulder_L  Hiproll_R   Shoulder_R  Hip  \
# 0 -90.1392        ...        -2016.000000   0.000000  2199.000000  0.0
# 1 -90.1584        ...        -2018.228261  -5.869565  2193.141304  0.0
# 2 -90.1798        ...        -2020.456522 -11.739130  2187.282609  0.0
# 3 -90.2022        ...        -2022.684783 -17.608696  2181.423913  0.0
# 4 -90.2185        ...        -2024.913043 -23.478261  2175.565217  0.0
#
#           Moe  Hip_R        Head  Shoulder_peach_L  Head_pitch  \
# 0  261.000000    0.0  916.000000            1072.0      -271.0
# 1  261.608696    0.0  917.586956            1072.0      -271.0
# 2  262.217391    0.0  919.173913            1072.0      -271.0
# 3  262.826087    0.0  920.760870            1072.0      -271.0
# 4  263.434783    0.0  922.347826            1072.0      -271.0
#
#    Shoulder_pitch_R
# 0           -1028.0
# 1           -1028.0
# 2           -1028.0
# 3           -1028.0
# 4           -1028.0
#
# [5 rows x 108 columns]

# %%
#cap_head = pd.concat(cap_headx,cap_heady,cap_headz)
dataset = pd.concat( [  full['76'],full['77'],full['78']] , axis=1 )
dataset.head()
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
import matplotlib.pyplot as plt
values = dataset.values
# specify columns to plot
groups = [0, 1, 2, 3]
i=1
plt.figure(figsize=(14,8))
for group in groups:
	plt.subplot(len(groups), 1, i)
	plt.plot(values[:, group])
	plt.title(dataset.columns[group], y=0.5, loc='right')
	i += 1
plt.show()

# %%
import numpy as np
values = dataset.values
values = dataset.astype(np.float32)
#values -= np.mean(values, axis = 0)
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# frame as supervised learning
#reframed = series_to_supervised(scaled, 1, 1)
time_step=3
n_features=3
reframed = series_to_supervised(scaled, time_step, 1)

print(reframed.head())
#reframed.head()
#values = scaled.values
# Out:
#    var1(t-3)  var2(t-3)  var3(t-3)  var4(t-3)  var1(t-2)  var2(t-2)  \
# 3   0.412781   0.526011   0.508022   0.678209   0.418129   0.529421
# 4   0.418129   0.529421   0.509774   0.678764   0.421799   0.531716
# 5   0.421799   0.531716   0.510982   0.679319   0.421625   0.531912
# 6   0.421625   0.531912   0.511256   0.679874   0.420697   0.531621
# 7   0.420697   0.531621   0.510959   0.680429   0.419909   0.531468
#
#    var3(t-2)  var4(t-2)  var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)   var1(t)  \
# 3   0.509774   0.678764   0.421799   0.531716   0.510982   0.679319  0.421625
# 4   0.510982   0.679319   0.421625   0.531912   0.511256   0.679874  0.420697
# 5   0.511256   0.679874   0.420697   0.531621   0.510959   0.680429  0.419909
# 6   0.510959   0.680429   0.419909   0.531468   0.510079   0.680985  0.418822
# 7   0.510079   0.680985   0.418822   0.530849   0.508875   0.681540  0.417390
#
#     var2(t)   var3(t)   var4(t)
# 3  0.531912  0.511256  0.679874
# 4  0.531621  0.510959  0.680429
# 5  0.531468  0.510079  0.680985
# 6  0.530849  0.508875  0.681540
# 7  0.529380  0.507321  0.682095

# %%
values = reframed.values
train = values[:8000,:]
val = values[8000:10000,:]
test = values[10000:,:]


n_obs = time_step*n_features
train_X,train_y = train[:,:n_obs],train[:,-n_features]
val_X,val_y = val[:,:n_obs],val[:,-n_features]#第一个多少行
test_X,test_y = test[:,:n_obs],test[:,-n_features]
print(train_X.shape,train_y.shape)
train_X[0,:]
# Out:
# (8000, 9) (8000,)
# array([0.41278109, 0.52601126, 0.50802222, 0.67820916, 0.41812888,
#        0.52942076, 0.50977422, 0.67876424, 0.42179948])

# %%
train_y
# Out:
# array([0.67820916, 0.67876424, 0.6793193 , ..., 0.66210297, 0.66176985,
#        0.66176985])

# %%
train_X = train_X.reshape(train_X.shape[0],time_step,n_features)
val_X = val_X.reshape(val_X.shape[0],time_step,n_features)
test_X = test_X.reshape(test_X.shape[0],time_step,n_features)
print(train_X.shape,train_y.shape,val_X.shape,val_y.shape,test_X.shape,test_y.shape)
# Out:
# (8000, 3, 3) (8000,) (2000, 3, 3) (2000,) (1417, 3, 3) (1417,)

# %%
# design network
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
#model.add(LSTM(20,return_sequences=True))
model.add(LSTM(10))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
history = model.fit(train_X, train_y, epochs=50, batch_size=30, validation_data=(val_X, val_y), verbose=2, shuffle=False)
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.show()
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
#  - 8s - loss: 0.0931 - val_loss: 0.0812
# Epoch 2/50
#  - 3s - loss: 0.0465 - val_loss: 0.0952
# Epoch 3/50
#  - 3s - loss: 0.0415 - val_loss: 0.1069
# Epoch 4/50
#  - 3s - loss: 0.0393 - val_loss: 0.1186
# Epoch 5/50
#  - 3s - loss: 0.0360 - val_loss: 0.1310
# Epoch 6/50
#  - 3s - loss: 0.0326 - val_loss: 0.0844
# Epoch 7/50
#  - 3s - loss: 0.0275 - val_loss: 0.0751
# Epoch 8/50
#  - 3s - loss: 0.0256 - val_loss: 0.0707
# Epoch 9/50
#  - 3s - loss: 0.0235 - val_loss: 0.0509
# Epoch 10/50
#  - 3s - loss: 0.0221 - val_loss: 0.0611
# Epoch 11/50
#  - 3s - loss: 0.0205 - val_loss: 0.0371
# Epoch 12/50
#  - 3s - loss: 0.0202 - val_loss: 0.0395
# Epoch 13/50
#  - 3s - loss: 0.0185 - val_loss: 0.0316
# Epoch 14/50
#  - 3s - loss: 0.0166 - val_loss: 0.0269
# Epoch 15/50
#  - 3s - loss: 0.0147 - val_loss: 0.0235
# Epoch 16/50
#  - 3s - loss: 0.0136 - val_loss: 0.0158
# Epoch 17/50
#  - 3s - loss: 0.0136 - val_loss: 0.0195
# Epoch 18/50
#  - 3s - loss: 0.0111 - val_loss: 0.0220
# Epoch 19/50
#  - 4s - loss: 0.0107 - val_loss: 0.0222
# Epoch 20/50
#  - 3s - loss: 0.0120 - val_loss: 0.0209
# Epoch 21/50
#  - 3s - loss: 0.0099 - val_loss: 0.0211
# Epoch 22/50
#  - 3s - loss: 0.0111 - val_loss: 0.0170
# Epoch 23/50
#  - 3s - loss: 0.0098 - val_loss: 0.0191
# Epoch 24/50
#  - 3s - loss: 0.0098 - val_loss: 0.0304
# Epoch 25/50
#  - 3s - loss: 0.0110 - val_loss: 0.0197
# Epoch 26/50
#  - 3s - loss: 0.0101 - val_loss: 0.0148
# Epoch 27/50
#  - 3s - loss: 0.0091 - val_loss: 0.0156
# Epoch 28/50
#  - 3s - loss: 0.0101 - val_loss: 0.0152
# Epoch 29/50
#  - 3s - loss: 0.0104 - val_loss: 0.0230
# Epoch 30/50
#  - 3s - loss: 0.0100 - val_loss: 0.0241
# Epoch 31/50
#  - 3s - loss: 0.0099 - val_loss: 0.0237
# Epoch 32/50
#  - 3s - loss: 0.0098 - val_loss: 0.0245
# Epoch 33/50
#  - 3s - loss: 0.0097 - val_loss: 0.0192
# Epoch 34/50
#  - 3s - loss: 0.0106 - val_loss: 0.0190
# Epoch 35/50
#  - 3s - loss: 0.0103 - val_loss: 0.0213
# Epoch 36/50
#  - 3s - loss: 0.0111 - val_loss: 0.0218
# Epoch 37/50
#  - 3s - loss: 0.0103 - val_loss: 0.0214
# Epoch 38/50
#  - 3s - loss: 0.0096 - val_loss: 0.0186
# Epoch 39/50
#  - 3s - loss: 0.0087 - val_loss: 0.0177
# Epoch 40/50
#  - 3s - loss: 0.0100 - val_loss: 0.0173
# Epoch 41/50
#  - 3s - loss: 0.0108 - val_loss: 0.0555
# Epoch 42/50
#  - 3s - loss: 0.0115 - val_loss: 0.0151
# Epoch 43/50
#  - 3s - loss: 0.0099 - val_loss: 0.0220
# Epoch 44/50
#  - 3s - loss: 0.0087 - val_loss: 0.0191
# Epoch 45/50
#  - 3s - loss: 0.0093 - val_loss: 0.0177
# Epoch 46/50
#  - 3s - loss: 0.0091 - val_loss: 0.0242
# Epoch 47/50
#  - 3s - loss: 0.0116 - val_loss: 0.0479
# Epoch 48/50
#  - 3s - loss: 0.0109 - val_loss: 0.0267
# Epoch 49/50
#  - 3s - loss: 0.0117 - val_loss: 0.0201
# Epoch 50/50
#  - 3s - loss: 0.0096 - val_loss: 0.0219

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], time_step*n_features))
test_X.shape
# Out:
# (1417, 9)

# %%
# invert scaling for forecast
inv_yhat = concatenate((yhat, test_X[:, -3:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, -3:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 2.921

# %%
plt.figure()
plt.plot(inv_yhat, label = 'predict')
plt.plot(inv_y, label = 'true')
plt.legend()
plt.show()

# %%
train_X[0,:]
# Out:
# array([[0.41278109, 0.52601126, 0.50802222],
#        [0.67820916, 0.41812888, 0.52942076],
#        [0.50977422, 0.67876424, 0.42179948]])

# %%
# Out:
# array([[0.62037974],
#        [0.62135553],
#        [0.62210769],
#        ...,
#        [0.84352293],
#        [0.84258163],
#        [0.84229881]])
